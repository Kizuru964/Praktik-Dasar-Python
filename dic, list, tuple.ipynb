# %%
# Program dic
dic = {'Mahasiswa':['Bahar'], 'prodi':'Mekatronika', 'kuliah':'pyton'}
for i in dic['Mahasiswa']:
    print(i, ':', dic['prodi'])
# Out:
# Bahar : Mekatronika

# %%
# Program list
list = [10, 20, 30, 40, 50]

print('index list')
print(list[0])
print(list[2])
print(list[4])
print(list[-1])
print(list[-2])
print(list[-5])
print('banyaknya element:')
print(len(list))
# Out:
# index list
# 10
# 30
# 50
# 50
# 40
# 10
# banyaknya element:
# 5

# %%
# Program Tuple
hari = ('Minggu', 'Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu')
print(type(hari))

print(hari)
print(hari[0])
print(hari[2])
print(hari[5])
# Out:
# <class 'tuple'>
# ('Minggu', 'Senin', 'Selasa', 'Rabu', 'Kamis', 'Jumat', 'Sabtu')
# Minggu
# Selasa
# Jumat
